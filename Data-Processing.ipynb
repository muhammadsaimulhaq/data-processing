# %% [markdown]
# # Pandas Learning

# %%
print("running")
# Out:
# running

# %%
import pandas as pd
df=pd.read_csv("data.csv")

# %%
df.shape
# Out:
# (61, 10)

# %%
df.head(4)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0

# %%
df.tail(3)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
df.sample(3)
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 40     53  nissan      sedan        94.5   165.3         ohc             four
# 21     30   isuzu      sedan        94.3   170.7         ohc             four
# 60     88   volvo      wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 40          55               45   7099.0
# 21          78               24   6785.0
# 60         114               23  13415.0

# %%
df.rename(columns={"body-style":"body","wheel-base":"wheel","engine-type":"engine","num-of-cylinders":"cylinders","average-mileage":"average"},inplace=True)

# %%
df.head(2)
# Out:
#    index      company         body  wheel  length engine cylinders  \
# 0      0  alfa-romero  convertible   88.6   168.8   dohc      four
# 1      1  alfa-romero  convertible   88.6   168.8   dohc      four
#
#    horsepower  average    price
# 0         111       21  13495.0
# 1         111       21  16500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       61 non-null     int64
#  1   company     61 non-null     object
#  2   body        61 non-null     object
#  3   wheel       61 non-null     float64
#  4   length      61 non-null     float64
#  5   engine      61 non-null     object
#  6   cylinders   61 non-null     object
#  7   horsepower  61 non-null     int64
#  8   average     61 non-null     int64
#  9   price       58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
df.describe()
# Out:
#            index       wheel      length  horsepower    average         price
# count  61.000000   61.000000   61.000000   61.000000  61.000000     58.000000
# mean   40.885246   98.481967  173.098361  107.852459  25.803279  15387.000000
# std    25.429706    6.679234   14.021846   53.524398   8.129821  11320.259841
# min     0.000000   88.400000  141.100000   48.000000  13.000000   5151.000000
# 25%    18.000000   94.500000  159.100000   68.000000  19.000000   6808.500000
# 50%    39.000000   96.300000  171.200000  100.000000  25.000000  11095.000000
# 75%    61.000000  101.200000  177.300000  123.000000  31.000000  18120.500000
# max    88.000000  120.900000  208.100000  288.000000  47.000000  45400.000000

# %%
df.describe(include="all")
# Out:
#             index company   body       wheel      length engine cylinders  \
# count   61.000000      61     61   61.000000   61.000000     61        61
# unique        NaN      16      5         NaN         NaN      7         7
# top           NaN  toyota  sedan         NaN         NaN    ohc      four
# freq          NaN       7     32         NaN         NaN     46        39
# mean    40.885246     NaN    NaN   98.481967  173.098361    NaN       NaN
# std     25.429706     NaN    NaN    6.679234   14.021846    NaN       NaN
# min      0.000000     NaN    NaN   88.400000  141.100000    NaN       NaN
# 25%     18.000000     NaN    NaN   94.500000  159.100000    NaN       NaN
# 50%     39.000000     NaN    NaN   96.300000  171.200000    NaN       NaN
# 75%     61.000000     NaN    NaN  101.200000  177.300000    NaN       NaN
# max     88.000000     NaN    NaN  120.900000  208.100000    NaN       NaN
#
#         horsepower    average         price
# ...

# %%
a = df['price']
a
# Out:
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, Length: 61, dtype: float64

# %%
b = df[["company","price"]]
b.head(4)
# Out:
#        company    price
# 0  alfa-romero  13495.0
# 1  alfa-romero  16500.0
# 2  alfa-romero  16500.0
# 3         audi  13950.0

# %%
df['company'].value_counts()
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: count, dtype: int64

# %%
df['company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='company'>

# %%
df['company'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='company'>

# %%
df['company'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df['company'].value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='company'>

# %%
df['company'].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df['company'].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df['company'].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['company'].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df['company'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='company'>

# %%
df.describe(include="all").iloc[[0,10]]
# Out:
#        index company body  wheel  length engine cylinders  horsepower  \
# count   61.0      61   61   61.0    61.0     61        61        61.0
# max     88.0     NaN  NaN  120.9   208.1    NaN       NaN       288.0
#
#        average    price
# count     61.0     58.0
# max       47.0  45400.0

# %%
df.describe(include="all").loc[["min","max"]]
# Out:
#      index company body  wheel  length engine cylinders  horsepower  average  \
# min    0.0     NaN  NaN   88.4   141.1    NaN       NaN        48.0     13.0
# max   88.0     NaN  NaN  120.9   208.1    NaN       NaN       288.0     47.0
#
#        price
# min   5151.0
# max  45400.0

# %%
df["price"].mean()
# Out:
# 15387.0

# %%
df["price"].mode()
# Out:
# 0    16500.0
# Name: price, dtype: float64

# %%
df["price"].median()
# Out:
# 11095.0

# %%
df["price"].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# Name: price, Length: 61, dtype: bool

# %%
pd.set_option("display.max_rows",None)
df["price"].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47     True
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# Name: price, dtype: bool

# %%
df.isnull()
# Out:
#     index  company   body  wheel  length  engine  cylinders  horsepower  \
# 0   False    False  False  False   False   False      False       False
# 1   False    False  False  False   False   False      False       False
# 2   False    False  False  False   False   False      False       False
# 3   False    False  False  False   False   False      False       False
# 4   False    False  False  False   False   False      False       False
# 5   False    False  False  False   False   False      False       False
# 6   False    False  False  False   False   False      False       False
# 7   False    False  False  False   False   False      False       False
# 8   False    False  False  False   False   False      False       False
# 9   False    False  False  False   False   False      False       False
# 10  False    False  False  False   False   False      False       False
# 11  False    False  False  False   False   False      False       False
# ...

# %%
df.isnull().sum()
# Out:
# index         0
# company       0
# body          0
# wheel         0
# length        0
# engine        0
# cylinders     0
# horsepower    0
# average       0
# price         3
# dtype: int64

# %%
df[df['price'].isnull()]
# Out:
#     index  company       body  wheel  length engine cylinders  horsepower  \
# 22     31    isuzu      sedan   94.5   155.9    ohc      four          70
# 23     32    isuzu      sedan   94.5   155.9    ohc      four          70
# 47     63  porsche  hatchback   98.4   175.7  dohcv     eight         288
#
#     average  price
# 22       38    NaN
# 23       38    NaN
# 47       17    NaN

# %%
df["final_price"] = df["price"].fillna(df["price"].mean())

# %%
df[df["price"].isnull()]
# Out:
#     index  company       body  wheel  length engine cylinders  horsepower  \
# 22     31    isuzu      sedan   94.5   155.9    ohc      four          70
# 23     32    isuzu      sedan   94.5   155.9    ohc      four          70
# 47     63  porsche  hatchback   98.4   175.7  dohcv     eight         288
#
#     average  price  final_price
# 22       38    NaN      15387.0
# 23       38    NaN      15387.0
# 47       17    NaN      15387.0

# %% [markdown]
# # Groupby

# %%
df.groupby("company").describe()
# Out:
#               index                                                  wheel  \
#               count   mean       std   min    25%   50%    75%   max count
# company
# alfa-romero     3.0   1.00  1.000000   0.0   0.50   1.0   1.50   2.0   3.0
# audi            4.0   4.50  1.290994   3.0   3.75   4.5   5.25   6.0   4.0
# bmw             6.0  12.00  2.366432   9.0  10.25  12.0  13.75  15.0   6.0
# chevrolet       3.0  17.00  1.000000  16.0  16.50  17.0  17.50  18.0   3.0
# dodge           2.0  19.50  0.707107  19.0  19.25  19.5  19.75  20.0   2.0
# honda           3.0  28.00  1.000000  27.0  27.50  28.0  28.50  29.0   3.0
# isuzu           3.0  31.00  1.000000  30.0  30.50  31.0  31.50  32.0   3.0
# jaguar          3.0  34.00  1.000000  33.0  33.50  34.0  34.50  35.0   3.0
# mazda           5.0  38.60  2.701851  36.0  37.00  38.0  39.00  43.0   5.0
# mercedes-benz   4.0  45.50  1.290994  44.0  44.75  45.5  46.25  47.0   4.0
# ...
